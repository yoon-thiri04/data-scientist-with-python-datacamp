# %%
import pandas as pd

df=pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.shape #rows and columns
# Out:
# (768, 9)

# %%
df.iloc[:,3]
# Out:
# 0      35
# 1      29
# 2       0
# 3      23
# 4      35
#        ..
# 763    48
# 764    27
# 765    23
# 766     0
# 767    31
# Name: SkinThickness, Length: 768, dtype: int64

# %%
df.values
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %%
df.columns #column names
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.index #row numbers or row names
# Out:
# RangeIndex(start=0, stop=768, step=1)

# %%
df.sort_values('Glucose',ascending=False)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 661            1      199             76             43        0  42.9
# 561            0      198             66             32      274  41.3
# 228            4      197             70             39      744  36.7
# 8              2      197             70             45      543  30.5
# 579            2      197             70             99        0  34.7
# ..           ...      ...            ...            ...      ...   ...
# 342            1        0             68             35        0  32.0
# 349            5        0             80             32        0  41.0
# 502            6        0             68             41        0  39.0
# 182            1        0             74             20       23  27.7
# 75             1        0             48             20        0  24.7
#
#      DiabetesPedigreeFunction  Age  Outcome  total
# 661                     1.394   22        1   64.9
# ...

# %%
df.sort_values('BloodPressure')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 347            3      116              0              0        0  23.5
# 494            3       80              0              0        0   0.0
# 222            7      119              0              0        0  25.2
# 81             2       74              0              0        0   0.0
# 78             0      131              0              0        0  43.2
# ..           ...      ...            ...            ...      ...   ...
# 549            4      189            110             31        0  28.5
# 43             9      171            110             24      240  45.4
# 177            0      129            110             46      130  67.1
# 691           13      158            114              0        0  42.3
# 106            1       96            122              0        0  22.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 347                     0.187   23        0
# ...

# %%
brics=pd.read_csv("brics.csv",index_col=0)
brics.head(2)
# Out:
#    country   capital  area  population
# BR  Brazil  Brasilia   8.9       200.4
# RU  Russia    Moscow  14.6       147.5

# %%
for lab,row in brics.iterrows():
    print(lab,row)
# Out:
# BR country         Brazil
# capital       Brasilia
# area               8.9
# population       200.4
# Name: BR, dtype: object
# RU country       Russia
# capital       Moscow
# area            14.6
# population     147.5
# Name: RU, dtype: object
# GR country       Germany
# capital        Berlin
# area              5.6
# population       60.5
# Name: GR, dtype: object
# IN country           India
# capital       New Delhi
# area               5.46
# population       1225.0
# Name: IN, dtype: object
# NW country       Norway
# capital         Olso
# area            5.67
# population      80.6
# Name: NW, dtype: object

# %%
brics
# Out:
#     country    capital   area  population
# BR   Brazil   Brasilia   8.90       200.4
# RU   Russia     Moscow  14.60       147.5
# GR  Germany     Berlin   5.60        60.5
# IN    India  New Delhi   5.46      1225.0
# NW   Norway       Olso   5.67        80.6

# %%
for lab,row in brics.iterrows():
    print(lab+":"+str(row['area']>10))
# Out:
# BR:False
# RU:True
# GR:False
# IN:False
# NW:False

# %%
brics.loc['BR']
# Out:
# country         Brazil
# capital       Brasilia
# area               8.9
# population       200.4
# Name: BR, dtype: object

# %%
brics[['area']]
# Out:
#      area
# BR   8.90
# RU  14.60
# GR   5.60
# IN   5.46
# NW   5.67

# %%
brics.loc[:,'area']
# Out:
# BR     8.90
# RU    14.60
# GR     5.60
# IN     5.46
# NW     5.67
# Name: area, dtype: float64

# %%
brics.iloc[:,2]
# Out:
# BR     8.90
# RU    14.60
# GR     5.60
# IN     5.46
# NW     5.67
# Name: area, dtype: float64

# %%
brics.loc[['BR','GR'],['population']]
# Out:
#     population
# BR       200.4
# GR        60.5

# %%
brics.iloc[[1,2],[1]]
# Out:
#    capital
# RU  Moscow
# GR  Berlin

# %%
brics.iloc[[1]]
# Out:
#    country capital  area  population
# RU  Russia  Moscow  14.6       147.5

# %%
#apply function to add new column
brics['country_name_length']=brics.loc[:,'country'].apply(len)
brics
# Out:
#     country    capital   area  population  country_name_length
# BR   Brazil   Brasilia   8.90       200.4                    6
# RU   Russia     Moscow  14.60       147.5                    6
# GR  Germany     Berlin   5.60        60.5                    7
# IN    India  New Delhi   5.46      1225.0                    5
# NW   Norway       Olso   5.67        80.6                    6

# %%
brics['area_greater_than_10']=brics['area'].apply(lambda x:x>10)
brics
# Out:
#     country    capital   area  population  country_name_length  \
# BR   Brazil   Brasilia   8.90       200.4                    6
# RU   Russia     Moscow  14.60       147.5                    6
# GR  Germany     Berlin   5.60        60.5                    7
# IN    India  New Delhi   5.46      1225.0                    5
# NW   Norway       Olso   5.67        80.6                    6
#
#     area_greater_than_10
# BR                 False
# RU                  True
# GR                 False
# IN                 False
# NW                 False

# %%
df.iloc[1:5,[0,1]]
# Out:
#    Pregnancies  Glucose
# 1            1       85
# 2            8      183
# 3            1       89
# 4            0      137

# %%
df.iloc[[2,3],1:5]
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin
# 2      183             64              0        0
# 3       89             66             23       94

# %%
brics['population_big']=brics.loc[:,'population'].apply(lambda x:x>100)

# %%
df.sort_values(['Glucose','Insulin'],ascending=[True,False])
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 182            1        0             74             20       23  27.7
# 75             1        0             48             20        0  24.7
# 342            1        0             68             35        0  32.0
# 349            5        0             80             32        0  41.0
# 502            6        0             68             41        0  39.0
# ..           ...      ...            ...            ...      ...   ...
# 8              2      197             70             45      543  30.5
# 408            8      197             74              0        0  25.9
# 579            2      197             70             99        0  34.7
# 561            0      198             66             32      274  41.3
# 661            1      199             76             43        0  42.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 182                     0.299   21        0
# ...

# %%
df[['Glucose']]
# Out:
#      Glucose
# 0        148
# 1         85
# 2        183
# 3         89
# 4        137
# ..       ...
# 763      101
# 764      122
# 765      121
# 766      126
# 767       93
#
# [768 rows x 1 columns]

# %%
df[['Glucose','BloodPressure']]
# Out:
#      Glucose  BloodPressure
# 0        148             72
# 1         85             66
# 2        183             64
# 3         89             66
# 4        137             40
# ..       ...            ...
# 763      101             76
# 764      122             70
# 765      121             72
# 766      126             60
# 767       93             70
#
# [768 rows x 2 columns]

# %%
df['Glucose']>100
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 763     True
# 764     True
# 765     True
# 766     True
# 767    False
# Name: Glucose, Length: 768, dtype: bool

# %%
df[df['Glucose']>150]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2              8      183             64              0        0  23.3
# 8              2      197             70             45      543  30.5
# 11            10      168             74              0        0  38.0
# 13             1      189             60             23      846  30.1
# 14             5      166             72             19      175  25.8
# ..           ...      ...            ...            ...      ...   ...
# 749            6      162             62              0        0  24.3
# 753            0      181             88             44      510  43.3
# 754            8      154             78             32        0  32.4
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 2                       0.672   32        1
# ...

# %%
df[df['Glucose']==100]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 15             7      100              0              0        0  30.0
# 57             0      100             88             60      110  46.8
# 70             2      100             66             20       90  32.9
# 87             2      100             68             25       71  38.5
# 136            0      100             70             26       50  30.8
# 163            2      100             64             23        0  29.7
# 224            1      100             66             15       56  23.6
# 275            2      100             70             52       57  40.5
# 298           14      100             78             25      184  36.6
# 389            3      100             68             23       81  31.6
# 390            1      100             66             29      196  32.0
# 446            1      100             72             12       70  25.3
# ...

# %%
df[(df['Glucose']==100) & (df['BloodPressure']>60)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 57             0      100             88             60      110  46.8
# 70             2      100             66             20       90  32.9
# 87             2      100             68             25       71  38.5
# 136            0      100             70             26       50  30.8
# 163            2      100             64             23        0  29.7
# 224            1      100             66             15       56  23.6
# 275            2      100             70             52       57  40.5
# 298           14      100             78             25      184  36.6
# 389            3      100             68             23       81  31.6
# 390            1      100             66             29      196  32.0
# 446            1      100             72             12       70  25.3
# 540            8      100             74             40      215  39.4
# ...

# %%
is_in=df['Glucose'].isin([100])
df[is_in]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 15             7      100              0              0        0  30.0
# 57             0      100             88             60      110  46.8
# 70             2      100             66             20       90  32.9
# 87             2      100             68             25       71  38.5
# 136            0      100             70             26       50  30.8
# 163            2      100             64             23        0  29.7
# 224            1      100             66             15       56  23.6
# 275            2      100             70             52       57  40.5
# 298           14      100             78             25      184  36.6
# 389            3      100             68             23       81  31.6
# 390            1      100             66             29      196  32.0
# 446            1      100             72             12       70  25.3
# ...

# %% [markdown]
# ## Exercises

# %%
Glucose_and_Age_in_sorted_descending=df.sort_values(['Glucose','Age'],ascending=[True,False])
Glucose_and_Age_in_sorted_descending.head(6)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 502            6        0             68             41        0  39.0
# 349            5        0             80             32        0  41.0
# 75             1        0             48             20        0  24.7
# 342            1        0             68             35        0  32.0
# 182            1        0             74             20       23  27.7
# 62             5       44             62              0        0  25.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 502                     0.727   41        1
# 349                     0.346   37        1
# 75                      0.140   22        0
# 342                     0.389   22        0
# 182                     0.299   21        0
# 62                      0.587   36        0

# %%
Glucose_and_BloodPressure=df[['Glucose','BloodPressure']]
Glucose_and_BloodPressure.head()
# Out:
#    Glucose  BloodPressure
# 0      148             72
# 1       85             66
# 2      183             64
# 3       89             66
# 4      137             40

# %% [markdown]
# ### Subsetting rows
# A large part of data science is about finding which bits of your dataset are interesting. One of the simplest techniques for this is to find a subset of rows that match some criteria. This is sometimes known as `filtering rows or selecting rows`.

# %%
# The Mojave Desert states
canu = ["California", "Arizona", "Nevada", "Utah"]

# Filter for rows in the Mojave Desert states
mojave_homelessness = homelessness[homelessness['state'].isin(canu)]

# See the result
print(mojave_homelessness)

# %%
df['BloodPressure_2x']=df['BloodPressure'].apply(lambda x: 2*x)

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  BloodPressure_2x
# ...

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df['total']=df['BMI']+df['Age']

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  total
# 0                       0.627   50        1   83.6
# ...

# %%
df['Age'].min()
# Out:
# 21

# %%
df['Age'].mean()
# Out:
# 33.240885416666664

# %%
df['Age'].max()
# Out:
# 81

# %%
df[df['Age'].isin([50,30])].head(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 5              5      116             74              0        0  25.6
# 10             4      110             92              0        0  37.6
# 21             8       99             84              0        0  35.4
# 52             5       88             66             21       23  24.4
# 126            3      120             70             30      135  42.9
# 132            3      170             64             37      225  34.5
# 256            3      111             56             39        0  30.1
# 300            0      167              0              0        0  32.3
# 309            2      124             68             28      205  32.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 5                       0.201   30        0
# 10                      0.191   30        0
# ...

# %%
df[df['Age']>60].sort_values('Age',ascending=False).head()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 459            9      134             74             33       60  25.9
# 453            2      119              0              0        0  19.6
# 666            4      145             82             18        0  32.5
# 684            5      136             82              0        0   0.0
# 123            5      132             80              0        0  26.8
#
#      DiabetesPedigreeFunction  Age  Outcome
# 459                     0.460   81        0
# 453                     0.832   72        0
# 666                     0.235   70        1
# 684                     0.640   69        0
# 123                     0.186   69        0

# %%
df[(df['Age']<50) | (df['Glucose']!=100)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df['add_age_ten']=df['Age']+10
my_df=df[(df['Age']<50) & (df['Glucose']!=100)]
sort_df=my_df.sort_values('add_age_ten',ascending=False)

# %%
sort_df.head()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 670            6      165             68             26      168  33.6
# 245            9      184             85             15        0  30.0
# 701            6      125             78             31        0  27.6
# 355            9      165             88              0        0  30.4
# 345            8      126             88             36      108  38.5
#
#      DiabetesPedigreeFunction  Age  Outcome  add_age_ten
# 670                     0.631   49        0           59
# 245                     1.213   49        1           59
# 701                     0.565   49        1           59
# 355                     0.302   49        1           59
# 345                     0.349   49        0           59

# %%
sort_df.iloc[0:4,[1,4]]
# Out:
#      Glucose  Insulin
# 670      165      168
# 245      184        0
# 701      125        0
# 355      165        0

# %%
sort_df.iloc[[0,3],[2,4]]
# Out:
#      BloodPressure  Insulin
# 670             68      168
# 355             88        0

# %%
age_greater_40=sort_df[sort_df['Age']>40]

# %%
age_greater_40.head()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 670            6      165             68             26      168  33.6
# 245            9      184             85             15        0  30.0
# 701            6      125             78             31        0  27.6
# 355            9      165             88              0        0  30.4
# 345            8      126             88             36      108  38.5
#
#      DiabetesPedigreeFunction  Age  Outcome  add_age_ten
# 670                     0.631   49        0           59
# 245                     1.213   49        1           59
# 701                     0.565   49        1           59
# 355                     0.302   49        1           59
# 345                     0.349   49        0           59

# %%
age_greater_50=sort_df[sort_df['Age'].apply(lambda x:x>40)]
age_greater_50.head(3)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 670            6      165             68             26      168  33.6
# 245            9      184             85             15        0  30.0
# 701            6      125             78             31        0  27.6
#
#      DiabetesPedigreeFunction  Age  Outcome  add_age_ten
# 670                     0.631   49        0           59
# 245                     1.213   49        1           59
# 701                     0.565   49        1           59

# %%
df['Age'].mean()
# Out:
# 33.240885416666664

# %%
df['Age'].median()
# Out:
# 29.0

# %%
df['Age'].sum()
# Out:
# 25529

# %%
df['Age'].var()
# Out:
# 138.30304589037365

# %%
#join function ==> string.join(iteratable)

my_dic={'name':'Yoon',
        'age':20,
        'status':'with Ko<3'}
my_separater='Love'

str=my_separater.join(my_dic)
str
# Out:
# 'nameLoveageLovestatus'

# %%
myTuple = ("John", "Peter", "Vicky")

x = "#".join(myTuple)

print(x)
# Out:
# John#Peter#Vicky
