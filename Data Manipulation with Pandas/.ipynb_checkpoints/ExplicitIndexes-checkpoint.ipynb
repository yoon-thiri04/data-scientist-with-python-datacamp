# %%
import pandas as pd
import numpy as np

df=pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df_five=df[:6]
df_five
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0

# %%
df_five.index=['Yoon','Thiri','Aung','Zin','Linn','Khant']

# %%
df_five
# Out:
#        Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Yoon             6      148             72             35        0  33.6
# Thiri            1       85             66             29        0  26.6
# Aung             8      183             64              0        0  23.3
# Zin              1       89             66             23       94  28.1
# Linn             0      137             40             35      168  43.1
# Khant            5      116             74              0        0  25.6
#
#        DiabetesPedigreeFunction  Age  Outcome
# Yoon                      0.627   50        1
# Thiri                     0.351   31        0
# Aung                      0.672   32        1
# Zin                       0.167   21        0
# Linn                      2.288   33        1
# Khant                     0.201   30        0

# %%
df_five.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df_five.index
# Out:
# Index(['Yoon', 'Thiri', 'Aung', 'Zin', 'Linn', 'Khant'], dtype='object')

# %% [markdown]
# ### Setting a column as an index

# %%
df_five_ind=df_five.set_index("Age")

# %%
df_five_ind.reset_index()
# for reset_index has the argument drop=True to permanently deleted the index col
# Out:
#    Age  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0   50            6      148             72             35        0  33.6
# 1   31            1       85             66             29        0  26.6
# 2   32            8      183             64              0        0  23.3
# 3   21            1       89             66             23       94  28.1
# 4   33            0      137             40             35      168  43.1
# 5   30            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Outcome
# 0                     0.627        1
# 1                     0.351        0
# 2                     0.672        1
# 3                     0.167        0
# 4                     2.288        1
# 5                     0.201        0

# %%
df_five_ind.reset_index(drop=True)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Outcome
# 0                     0.627        1
# 1                     0.351        0
# 2                     0.672        1
# 3                     0.167        0
# 4                     2.288        1
# 5                     0.201        0

# %%
df_five[df_five['SkinThickness'].isin([35])]
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Yoon            6      148             72             35        0  33.6
# Linn            0      137             40             35      168  43.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# Yoon                     0.627   50        1
# Linn                     2.288   33        1

# %%
df_five_ind=df_five.set_index('SkinThickness')

# %%
df_five_ind.loc[[35]]
# Out:
#                Pregnancies  Glucose  BloodPressure  Insulin   BMI  \
# SkinThickness
# 35                       6      148             72        0  33.6
# 35                       0      137             40      168  43.1
#
#                DiabetesPedigreeFunction  Age  Outcome
# SkinThickness
# 35                                0.627   50        1
# 35                                2.288   33        1

# %%
df_five_multi=df_five.set_index(['SkinThickness','Age'])

# %%
df_five_multi.loc[[35,0
                  ]]
# Out:
#                    Pregnancies  Glucose  BloodPressure  Insulin   BMI  \
# SkinThickness Age
# 35            50             6      148             72        0  33.6
#               33             0      137             40      168  43.1
# 0             32             8      183             64        0  23.3
#               30             5      116             74        0  25.6
#
#                    DiabetesPedigreeFunction  Outcome
# SkinThickness Age
# 35            50                      0.627        1
#               33                      2.288        1
# 0             32                      0.672        1
#               30                      0.201        0

# %%
df_five_multi.index
# Out:
# MultiIndex([(35, 50),
#             (29, 31),
#             ( 0, 32),
#             (23, 21),
#             (35, 33),
#             ( 0, 30)],
#            names=['SkinThickness', 'Age'])

# %%
df_five_multi.loc[[(35,50),(0,30)]]
# Out:
#                    Pregnancies  Glucose  BloodPressure  Insulin   BMI  \
# SkinThickness Age
# 35            50             6      148             72        0  33.6
# 0             30             5      116             74        0  25.6
#
#                    DiabetesPedigreeFunction  Outcome
# SkinThickness Age
# 35            50                      0.627        1
# 0             30                      0.201        0

# %%
df_five.groupby('Age')['SkinThickness'].mean()
# Out:
# Age
# 21    23.0
# 30     0.0
# 31    29.0
# 32     0.0
# 33    35.0
# 50    35.0
# Name: SkinThickness, dtype: float64

# %%
def pdf30(col):
    return col.quantile(0.3)

# %%
df_five.pivot_table(values='SkinThickness',index='Age',margins=True,fill_value=0,aggfunc=[pdf30,np.median])
# Out:
#             pdf30        median
#     SkinThickness SkinThickness
# Age
# 21           23.0            23
# 30            0.0             0
# 31           29.0            29
# 32            0.0             0
# 33           35.0            35
# 50           35.0            35
# All          11.5            26

# %%
dogs_df=pd.read_csv('dog.csv')

# %%
dogs=dogs_df[:5]

# %%
dogs
# Out:
#   AnimalName                              animalclass  \
# 0    Sheldon                Non-Standard - Concession
# 1       Coco                Non-Standard - Concession
# 2      Penny   Standard - Both desexed & microchipped
# 3      Daisy   Standard - Both desexed & microchipped
# 4        Max  Non-Standard - Not desexed/microchipped
#
#                      animalbreed animalcolour animalgender animaldesexed  \
# 0            German Shepherd Dog        Black            M             N
# 1           Jack Russell Terrier         Gold            F             N
# 2                         Beagle        Brown            F             Y
# 3  Cavalier King Charles Spaniel     Blenheim            F             Y
# 4                        Maltese        White            M             Y
#
#    suburb_name
# 0  NORTH HAVEN
# 1  NORTH HAVEN
# 2  NORTH HAVEN
# 3  NORTH HAVEN
# 4  NORTH HAVEN

# %%
dogs_ind=dogs.set_index('AnimalName')

# %%
dogs_ind.loc[['Sheldon','Coco']]
# Out:
#                           animalclass           animalbreed animalcolour  \
# AnimalName
# Sheldon     Non-Standard - Concession   German Shepherd Dog        Black
# Coco        Non-Standard - Concession  Jack Russell Terrier         Gold
#
#            animalgender animaldesexed  suburb_name
# AnimalName
# Sheldon               M             N  NORTH HAVEN
# Coco                  F             N  NORTH HAVEN

# %%
dog_multi=dogs.set_index(['AnimalName','animalcolour'])
dog_multi
# Out:
#                                                      animalclass  \
# AnimalName animalcolour
# Sheldon    Black                       Non-Standard - Concession
# Coco       Gold                        Non-Standard - Concession
# Penny      Brown          Standard - Both desexed & microchipped
# Daisy      Blenheim       Standard - Both desexed & microchipped
# Max        White         Non-Standard - Not desexed/microchipped
#
#                                            animalbreed animalgender  \
# AnimalName animalcolour
# Sheldon    Black                   German Shepherd Dog            M
# Coco       Gold                   Jack Russell Terrier            F
# Penny      Brown                                Beagle            F
# Daisy      Blenheim      Cavalier King Charles Spaniel            F
# Max        White                               Maltese            M
#
#                         animaldesexed  suburb_name
# AnimalName animalcolour
# ...

# %%
dog_multi.loc[['Sheldon','Coco','Max']]
# Out:
#                                                      animalclass  \
# AnimalName animalcolour
# Sheldon    Black                       Non-Standard - Concession
# Coco       Gold                        Non-Standard - Concession
# Max        White         Non-Standard - Not desexed/microchipped
#
#                                   animalbreed animalgender animaldesexed  \
# AnimalName animalcolour
# Sheldon    Black          German Shepherd Dog            M             N
# Coco       Gold          Jack Russell Terrier            F             N
# Max        White                      Maltese            M             Y
#
#                          suburb_name
# AnimalName animalcolour
# Sheldon    Black         NORTH HAVEN
# Coco       Gold          NORTH HAVEN
# Max        White         NORTH HAVEN

# %%
dog_multi
# Out:
#                                                      animalclass  \
# AnimalName animalcolour
# Sheldon    Black                       Non-Standard - Concession
# Coco       Gold                        Non-Standard - Concession
# Penny      Brown          Standard - Both desexed & microchipped
# Daisy      Blenheim       Standard - Both desexed & microchipped
# Max        White         Non-Standard - Not desexed/microchipped
#
#                                            animalbreed animalgender  \
# AnimalName animalcolour
# Sheldon    Black                   German Shepherd Dog            M
# Coco       Gold                   Jack Russell Terrier            F
# Penny      Brown                                Beagle            F
# Daisy      Blenheim      Cavalier King Charles Spaniel            F
# Max        White                               Maltese            M
#
#                         animaldesexed  suburb_name
# AnimalName animalcolour
# ...

# %%
# use tuple
dog_multi.loc[[('Sheldon','Black'), ('Coco','Gold')]]
# Out:
#                                        animalclass           animalbreed  \
# AnimalName animalcolour
# Sheldon    Black         Non-Standard - Concession   German Shepherd Dog
# Coco       Gold          Non-Standard - Concession  Jack Russell Terrier
#
#                         animalgender animaldesexed  suburb_name
# AnimalName animalcolour
# Sheldon    Black                   M             N  NORTH HAVEN
# Coco       Gold                    F             N  NORTH HAVEN

# %%
dog_multi.loc[[('Penny','Brown'),('Daisy',
                                 'Blenheim')],['animalbreed',
                                              'suburb_name']]
# Out:
#                                            animalbreed  suburb_name
# AnimalName animalcolour
# Penny      Brown                                Beagle  NORTH HAVEN
# Daisy      Blenheim      Cavalier King Charles Spaniel  NORTH HAVEN

# %%
dog_multi.sort_values(['animalgender','animaldesexed'],ascending=[True, False])
# Out:
#                                                      animalclass  \
# AnimalName animalcolour
# Penny      Brown          Standard - Both desexed & microchipped
# Daisy      Blenheim       Standard - Both desexed & microchipped
# Coco       Gold                        Non-Standard - Concession
# Max        White         Non-Standard - Not desexed/microchipped
# Sheldon    Black                       Non-Standard - Concession
#
#                                            animalbreed animalgender  \
# AnimalName animalcolour
# Penny      Brown                                Beagle            F
# Daisy      Blenheim      Cavalier King Charles Spaniel            F
# Coco       Gold                   Jack Russell Terrier            F
# Max        White                               Maltese            M
# Sheldon    Black                   German Shepherd Dog            M
#
#                         animaldesexed  suburb_name
# AnimalName animalcolour
# ...

# %%
dog_multi['animalbreed'].value_counts()
# Out:
# animalbreed
# German Shepherd Dog              1
# Jack Russell Terrier             1
# Beagle                           1
# Cavalier King Charles Spaniel    1
# Maltese                          1
# Name: count, dtype: int64

# %%
dog_multi['animalgender'].value_counts()
# Out:
# animalgender
# F    3
# M    2
# Name: count, dtype: int64

# %%
dog_multi['animalgender'].value_counts(normalize=True)
# Out:
# animalgender
# F    0.6
# M    0.4
# Name: proportion, dtype: float64

# %%
dog_multi['animalgender'].value_counts(sort=True)
# Out:
# animalgender
# F    3
# M    2
# Name: count, dtype: int64

# %%
dog_multi.sort_index()
# Out:
#                                                      animalclass  \
# AnimalName animalcolour
# Coco       Gold                        Non-Standard - Concession
# Daisy      Blenheim       Standard - Both desexed & microchipped
# Max        White         Non-Standard - Not desexed/microchipped
# Penny      Brown          Standard - Both desexed & microchipped
# Sheldon    Black                       Non-Standard - Concession
#
#                                            animalbreed animalgender  \
# AnimalName animalcolour
# Coco       Gold                   Jack Russell Terrier            F
# Daisy      Blenheim      Cavalier King Charles Spaniel            F
# Max        White                               Maltese            M
# Penny      Brown                                Beagle            F
# Sheldon    Black                   German Shepherd Dog            M
#
#                         animaldesexed  suburb_name
# AnimalName animalcolour
# ...

# %%
dog_multi.sort_index(level=['animalcolour'],ascending=True)
# Out:
#                                                      animalclass  \
# AnimalName animalcolour
# Sheldon    Black                       Non-Standard - Concession
# Daisy      Blenheim       Standard - Both desexed & microchipped
# Penny      Brown          Standard - Both desexed & microchipped
# Coco       Gold                        Non-Standard - Concession
# Max        White         Non-Standard - Not desexed/microchipped
#
#                                            animalbreed animalgender  \
# AnimalName animalcolour
# Sheldon    Black                   German Shepherd Dog            M
# Daisy      Blenheim      Cavalier King Charles Spaniel            F
# Penny      Brown                                Beagle            F
# Coco       Gold                   Jack Russell Terrier            F
# Max        White                               Maltese            M
#
#                         animaldesexed  suburb_name
# AnimalName animalcolour
# ...

# %%
dog_multi.sort_index(level=['animalcolour'])

# %% [markdown]
# ### Two problems
# - index values are just data
# - `Indexes` violate `tidy data` principles

# %% [markdown]
# Setting multi-level indexes
# Indexes can also be made out of multiple columns, forming a multi-level index (sometimes called a hierarchical index). There is a trade-off to using these.
#
# The benefit is that multi-level indexes make it more natural to reason about nested categorical variables. For example, in a clinical trial, you might have control and treatment groups. Then each test subject belongs to one or another group, and we can say that a test subject is nested inside the treatment group. Similarly, in the temperature dataset, the city is located in the country, so we can say a city is nested inside the country.
#
# The main downside is that the code for manipulating indexes is different from the code for manipulating columns, so you have to learn two syntaxes and keep track of how your data is represented.

# %%
# Index temperatures by country & city
temperatures_ind = temperatures.set_index(['country','city'])

# List of tuples: Brazil, Rio De Janeiro & Pakistan, Lahore
rows_to_keep = [('Brazil','Rio De Janeiro'),('Pakistan','Lahore')]

# Subset for rows to keep
print(temperatures_ind.loc[rows_to_keep])
