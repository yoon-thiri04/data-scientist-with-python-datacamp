# %%
import pandas as pd
import matplotlib.pyplot as plt

dogs=pd.read_csv('dog.csv')
dogs.head()
# Out:
#   AnimalName                              animalclass  \
# 0    Sheldon                Non-Standard - Concession
# 1       Coco                Non-Standard - Concession
# 2      Penny   Standard - Both desexed & microchipped
# 3      Daisy   Standard - Both desexed & microchipped
# 4        Max  Non-Standard - Not desexed/microchipped
#
#                      animalbreed animalcolour animalgender animaldesexed  \
# 0            German Shepherd Dog        Black            M             N
# 1           Jack Russell Terrier         Gold            F             N
# 2                         Beagle        Brown            F             Y
# 3  Cavalier King Charles Spaniel     Blenheim            F             Y
# 4                        Maltese        White            M             Y
#
#    suburb_name
# 0  NORTH HAVEN
# 1  NORTH HAVEN
# 2  NORTH HAVEN
# 3  NORTH HAVEN
# 4  NORTH HAVEN

# %%
doogdogs['animalcolour'].value_counts()
# Out:
# animalcolour
# Black             4148
# White             2991
# Tan               1333
# Brown             1017
# Brindle            644
# Gold               641
# Red                558
# Tri Colour         547
# Blue               333
# Cream              287
# Fawn               273
# Grey               247
# Chocolate          220
# Apricot            161
# Unknown            152
# Sable              137
# Salt                93
# Yellow              75
# Blenheim            74
# Dark Brindle        69
# Beige               59
# Blonde              55
# Caramel             54
# Sandy               54
# Liver               42
# Orange              33
# Wheaten             30
# Honey               30
# Silver              28
# Ginger              27
# Ruby                26
# Champagne           22
# Wolf Grey           18
# Rust                14
# Lemon               12
# Russett             11
# Multi Coloured       9
# Biscuit              8
# Charcoal             6
# ...
